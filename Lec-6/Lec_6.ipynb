# %%
import pandas as pd
import numpy as np

employees = {
    'Emp_ID': [10,20,30],
    'Name': ["hamdia",'faria','nadeeyah'],
    'Age': [20,np.nan, 19],
    'Salary': [50000, 60000,np.nan],
    'Department': ['IT','IT','Finance'],
    'Location' :['NewYork','islamabad', 'Karachi']
}
df = pd.DataFrame(employees)
print(df)
# Out:
#    Emp_ID      Name   Age   Salary Department   Location
# 0      10    hamdia  20.0  50000.0         IT    NewYork
# 1      20     faria   NaN  60000.0         IT  islamabad
# 2      30  nadeeyah  19.0      NaN    Finance    Karachi

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df.dropna(subset=['Salary'],inplace=True)
print(df)
# Out:
#    Emp_ID    Name   Age   Salary Department   Location
# 0      10  hamdia  20.0  50000.0         IT    NewYork
# 1      20   faria  19.5  60000.0         IT  islamabad
# <ipython-input-3-d26717088718>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
it_employees=df[df['Department']=="IT"]
print(it_employees)
# Out:
#    Emp_ID    Name   Age   Salary Department   Location
# 0      10  hamdia  20.0  50000.0         IT    NewYork
# 1      20   faria  19.5  60000.0         IT  islamabad

# %%
df['Experiance']=np.where(df['Salary']>50000,"Senior","Junior")
print(df)
# Out:
#    Emp_ID    Name   Age   Salary Department   Location Experiance
# 0      10  hamdia  20.0  50000.0         IT    NewYork     Junior
# 1      20   faria  19.5  60000.0         IT  islamabad     Senior

# %%
new_hires = {
    'Emp_ID': [106,107],
    'Name': ["Frank",'John'],
    'Age': [44,30],
    'Salary': [55000, 65000],
    'Department': ['HR','Finance'],
    'Location' :['France','Germany']

}
df_newhire = pd.DataFrame(new_hires)
df_final=pd.concat([df,df_newhire],ignore_index=True)
print(df_final)
df_final['Experience'] = np.where(df_final['Salary'] > 70000, 'Senior', 'Junior')
print(df_final)
# Out:
#    Emp_ID    Name   Age   Salary Department   Location Experiance
# 0      10  hamdia  20.0  50000.0         IT    NewYork     Junior
# 1      20   faria  19.5  60000.0         IT  islamabad     Senior
# 2     106   Frank  44.0  55000.0         HR     France        NaN
# 3     107    John  30.0  65000.0    Finance    Germany        NaN
#    Emp_ID    Name   Age   Salary Department   Location Experiance Experience
# 0      10  hamdia  20.0  50000.0         IT    NewYork     Junior     Junior
# 1      20   faria  19.5  60000.0         IT  islamabad     Senior     Junior
# 2     106   Frank  44.0  55000.0         HR     France        NaN     Junior
# 3     107    John  30.0  65000.0    Finance    Germany        NaN     Junior

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [10,20,30,40,50]
plt.plot(x,y, marker='o', linestyle='--', color='r', label = 'Line1')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line Plot')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.regplot(x=x, y=y, scatter_kws={'color':'pink'}, line_kws={'color':'red'})
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Scatter Plot with Seaborn Regression")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
# Generate 3D data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=z, cmap='plasma', s=100)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("3D Scatter Plot")
plt.show()
